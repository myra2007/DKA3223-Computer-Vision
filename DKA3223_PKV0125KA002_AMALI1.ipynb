# %%
# !unzip -o /content/Dataset.zip -d /content/
# Out:
# Archive:  /content/Dataset.zip
#    creating: /content/Dataset/
#    creating: /content/Dataset/data_dogcat/
#    creating: /content/Dataset/data_dogcat/test/
#    creating: /content/Dataset/data_dogcat/test/cats/
#   inflating: /content/Dataset/data_dogcat/test/cats/cat.1000.jpg
#   inflating: /content/Dataset/data_dogcat/test/cats/cat.1001.jpg
#   inflating: /content/Dataset/data_dogcat/test/cats/cat.1002.jpg
#   inflating: /content/Dataset/data_dogcat/test/cats/cat.1003.jpg
#   inflating: /content/Dataset/data_dogcat/test/cats/cat.1004.jpg
#   inflating: /content/Dataset/data_dogcat/test/cats/cat.1005.jpg
#   inflating: /content/Dataset/data_dogcat/test/cats/cat.1006.jpg
#   inflating: /content/Dataset/data_dogcat/test/cats/cat.1007.jpg
#   inflating: /content/Dataset/data_dogcat/test/cats/cat.1008.jpg
#   inflating: /content/Dataset/data_dogcat/test/cats/cat.1009.jpg
#   inflating: /content/Dataset/data_dogcat/test/cats/cat.1010.jpg
#   inflating: /content/Dataset/data_dogcat/test/cats/cat.1011.jpg
#   inflating: /content/Dataset/data_dogcat/test/cats/cat.1012.jpg
#   inflating: /content/Dataset/data_dogcat/test/cats/cat.1013.jpg
#   inflating: /content/Dataset/data_dogcat/test/cats/cat.1014.jpg
#   inflating: /content/Dataset/data_dogcat/test/cats/cat.1015.jpg
#   inflating: /content/Dataset/data_dogcat/test/cats/cat.1016.jpg
#   inflating: /content/Dataset/data_dogcat/test/cats/cat.1017.jpg
#   inflating: /content/Dataset/data_dogcat/test/cats/cat.1018.jpg
#   inflating: /content/Dataset/data_dogcat/test/cats/cat.1019.jpg
#   inflating: /content/Dataset/data_dogcat/test/cats/cat.1020.jpg
#   inflating: /content/Dataset/data_dogcat/test/cats/cat.1021.jpg
#   inflating: /content/Dataset/data_dogcat/test/cats/cat.1022.jpg
#   inflating: /content/Dataset/data_dogcat/test/cats/cat.1023.jpg
#   inflating: /content/Dataset/data_dogcat/test/cats/cat.1024.jpg
#   inflating: /content/Dataset/data_dogcat/test/cats/cat.1025.jpg
#   inflating: /content/Dataset/data_dogcat/test/cats/cat.1026.jpg
#   inflating: /content/Dataset/data_dogcat/test/cats/cat.1027.jpg
#   inflating: /content/Dataset/data_dogcat/test/cats/cat.1028.jpg
#   inflating: /content/Dataset/data_dogcat/test/cats/cat.1029.jpg
#   inflating: /content/Dataset/data_dogcat/test/cats/cat.1030.jpg
#   inflating: /content/Dataset/data_dogcat/test/cats/cat.1031.jpg
#   inflating: /content/Dataset/data_dogcat/test/cats/cat.1032.jpg
#   inflating: /content/Dataset/data_dogcat/test/cats/cat.1033.jpg
#   inflating: /content/Dataset/data_dogcat/test/cats/cat.1034.jpg
#   inflating: /content/Dataset/data_dogcat/test/cats/cat.1035.jpg
#   inflating: /content/Dataset/data_dogcat/test/cats/cat.1036.jpg
#   inflating: /content/Dataset/data_dogcat/test/cats/cat.1037.jpg
#   inflating: /content/Dataset/data_dogcat/test/cats/cat.1038.jpg
#   inflating: /content/Dataset/data_dogcat/test/cats/cat.1039.jpg
#   inflating: /content/Dataset/data_dogcat/test/cats/cat.1040.jpg
#   inflating: /content/Dataset/data_dogcat/test/cats/cat.1041.jpg
#   inflating: /content/Dataset/data_dogcat/test/cats/cat.1042.jpg
#   inflating: /content/Dataset/data_dogcat/test/cats/cat.1043.jpg
#   inflating: /content/Dataset/data_dogcat/test/cats/cat.1044.jpg
#   inflating: /content/Dataset/data_dogcat/test/cats/cat.1045.jpg
#   inflating: /content/Dataset/data_dogcat/test/cats/cat.1046.jpg
#   inflating: /content/Dataset/data_dogcat/test/cats/cat.1047.jpg
#   inflating: /content/Dataset/data_dogcat/test/cats/kucing.jpg
#   inflating: /content/Dataset/data_dogcat/test/cats/kucing1(1).jpg
#   inflating: /content/Dataset/data_dogcat/test/cats/kucing1.jpg
#    creating: /content/Dataset/data_dogcat/test/dogs/
#   inflating: /content/Dataset/data_dogcat/test/dogs/dog.1000.jpg
#   inflating: /content/Dataset/data_dogcat/test/dogs/dog.1001.jpg
#   inflating: /content/Dataset/data_dogcat/test/dogs/dog.1002.jpg
#   inflating: /content/Dataset/data_dogcat/test/dogs/dog.1003.jpg
#   inflating: /content/Dataset/data_dogcat/test/dogs/dog.1004.jpg
#   inflating: /content/Dataset/data_dogcat/test/dogs/dog.1005.jpg
#   inflating: /content/Dataset/data_dogcat/test/dogs/dog.1006.jpg
#   inflating: /content/Dataset/data_dogcat/test/dogs/dog.1007.jpg
#   inflating: /content/Dataset/data_dogcat/test/dogs/dog.1008.jpg
#   inflating: /content/Dataset/data_dogcat/test/dogs/dog.1009.jpg
#   inflating: /content/Dataset/data_dogcat/test/dogs/dog.1010.jpg
#   inflating: /content/Dataset/data_dogcat/test/dogs/dog.1011.jpg
#   inflating: /content/Dataset/data_dogcat/test/dogs/dog.1012.jpg
#   inflating: /content/Dataset/data_dogcat/test/dogs/dog.1013.jpg
#   inflating: /content/Dataset/data_dogcat/test/dogs/dog.1014.jpg
#   inflating: /content/Dataset/data_dogcat/test/dogs/dog.1015.jpg
#   inflating: /content/Dataset/data_dogcat/test/dogs/dog.1016.jpg
#   inflating: /content/Dataset/data_dogcat/test/dogs/dog.1017.jpg
#   inflating: /content/Dataset/data_dogcat/test/dogs/dog.1018.jpg
#   inflating: /content/Dataset/data_dogcat/test/dogs/dog.1019.jpg
#   inflating: /content/Dataset/data_dogcat/test/dogs/dog.1020.jpg
#   inflating: /content/Dataset/data_dogcat/test/dogs/dog.1021.jpg
#   inflating: /content/Dataset/data_dogcat/test/dogs/dog.1022.jpg
#   inflating: /content/Dataset/data_dogcat/test/dogs/dog.1023.jpg
#   inflating: /content/Dataset/data_dogcat/test/dogs/dog.1024.jpg
#   inflating: /content/Dataset/data_dogcat/test/dogs/dog.1025.jpg
#   inflating: /content/Dataset/data_dogcat/test/dogs/dog.1026.jpg
#   inflating: /content/Dataset/data_dogcat/test/dogs/dog.1027.jpg
#   inflating: /content/Dataset/data_dogcat/test/dogs/dog.1028.jpg
#   inflating: /content/Dataset/data_dogcat/test/dogs/dog.1029.jpg
#   inflating: /content/Dataset/data_dogcat/test/dogs/dog.1030.jpg
#   inflating: /content/Dataset/data_dogcat/test/dogs/dog.1031.jpg
#   inflating: /content/Dataset/data_dogcat/test/dogs/dog.1032.jpg
#   inflating: /content/Dataset/data_dogcat/test/dogs/dog.1033.jpg
#   inflating: /content/Dataset/data_dogcat/test/dogs/dog.1034.jpg
#   inflating: /content/Dataset/data_dogcat/test/dogs/dog.1035.jpg
#   inflating: /content/Dataset/data_dogcat/test/dogs/dog.1036.jpg
#   inflating: /content/Dataset/data_dogcat/test/dogs/dog.1037.jpg
#   inflating: /content/Dataset/data_dogcat/test/dogs/dog.1038.jpg
#   inflating: /content/Dataset/data_dogcat/test/dogs/dog.1039.jpg
#   inflating: /content/Dataset/data_dogcat/test/dogs/dog.1040.jpg
#   inflating: /content/Dataset/data_dogcat/test/dogs/dog.1041.jpg
#   inflating: /content/Dataset/data_dogcat/test/dogs/dog.1042.jpg
#   inflating: /content/Dataset/data_dogcat/test/dogs/dog.1043.jpg
#   inflating: /content/Dataset/data_dogcat/test/dogs/dog.1044.jpg
#   inflating: /content/Dataset/data_dogcat/test/dogs/dog.1045.jpg
#   inflating: /content/Dataset/data_dogcat/test/dogs/dog.1046.jpg
#   inflating: /content/Dataset/data_dogcat/test/dogs/wolf.jpg
#    creating: /content/Dataset/data_dogcat/train/
#    creating: /content/Dataset/data_dogcat/train/cats/
#   inflating: /content/Dataset/data_dogcat/train/cats/cat.0.jpg
#   inflating: /content/Dataset/data_dogcat/train/cats/cat.1.jpg
#   inflating: /content/Dataset/data_dogcat/train/cats/cat.10.jpg
#   inflating: /content/Dataset/data_dogcat/train/cats/cat.11.jpg
#   inflating: /content/Dataset/data_dogcat/train/cats/cat.12.jpg
#   inflating: /content/Dataset/data_dogcat/train/cats/cat.13.jpg
#   inflating: /content/Dataset/data_dogcat/train/cats/cat.14.jpg
#   inflating: /content/Dataset/data_dogcat/train/cats/cat.15.jpg
#   inflating: /content/Dataset/data_dogcat/train/cats/cat.16.jpg
#   inflating: /content/Dataset/data_dogcat/train/cats/cat.17.jpg
#   inflating: /content/Dataset/data_dogcat/train/cats/cat.18.jpg
#   inflating: /content/Dataset/data_dogcat/train/cats/cat.19.jpg
#   inflating: /content/Dataset/data_dogcat/train/cats/cat.2.jpg
#   inflating: /content/Dataset/data_dogcat/train/cats/cat.20.jpg
#   inflating: /content/Dataset/data_dogcat/train/cats/cat.21.jpg
#   inflating: /content/Dataset/data_dogcat/train/cats/cat.22.jpg
#   inflating: /content/Dataset/data_dogcat/train/cats/cat.23.jpg
#   inflating: /content/Dataset/data_dogcat/train/cats/cat.24.jpg
#   inflating: /content/Dataset/data_dogcat/train/cats/cat.25.jpg
#   inflating: /content/Dataset/data_dogcat/train/cats/cat.26.jpg
#   inflating: /content/Dataset/data_dogcat/train/cats/cat.27.jpg
#   inflating: /content/Dataset/data_dogcat/train/cats/cat.28.jpg
#   inflating: /content/Dataset/data_dogcat/train/cats/cat.29.jpg
#   inflating: /content/Dataset/data_dogcat/train/cats/cat.3.jpg
#   inflating: /content/Dataset/data_dogcat/train/cats/cat.30.jpg
#   inflating: /content/Dataset/data_dogcat/train/cats/cat.31.jpg
#   inflating: /content/Dataset/data_dogcat/train/cats/cat.32.jpg
#   inflating: /content/Dataset/data_dogcat/train/cats/cat.33.jpg
#   inflating: /content/Dataset/data_dogcat/train/cats/cat.34.jpg
#   inflating: /content/Dataset/data_dogcat/train/cats/cat.35.jpg
#   inflating: /content/Dataset/data_dogcat/train/cats/cat.36.jpg
#   inflating: /content/Dataset/data_dogcat/train/cats/cat.37.jpg
#   inflating: /content/Dataset/data_dogcat/train/cats/cat.38.jpg
#   inflating: /content/Dataset/data_dogcat/train/cats/cat.39.jpg
#   inflating: /content/Dataset/data_dogcat/train/cats/cat.4.jpg
#   inflating: /content/Dataset/data_dogcat/train/cats/cat.40.jpg
#   inflating: /content/Dataset/data_dogcat/train/cats/cat.41.jpg
#   inflating: /content/Dataset/data_dogcat/train/cats/cat.42.jpg
#   inflating: /content/Dataset/data_dogcat/train/cats/cat.43.jpg
#   inflating: /content/Dataset/data_dogcat/train/cats/cat.44.jpg
#   inflating: /content/Dataset/data_dogcat/train/cats/cat.45.jpg
#   inflating: /content/Dataset/data_dogcat/train/cats/cat.46.jpg
#   inflating: /content/Dataset/data_dogcat/train/cats/cat.47.jpg
#   inflating: /content/Dataset/data_dogcat/train/cats/cat.48.jpg
#   inflating: /content/Dataset/data_dogcat/train/cats/cat.49.jpg
#   inflating: /content/Dataset/data_dogcat/train/cats/cat.5.jpg
#   inflating: /content/Dataset/data_dogcat/train/cats/cat.50.jpg
#   inflating: /content/Dataset/data_dogcat/train/cats/cat.51.jpg
#   inflating: /content/Dataset/data_dogcat/train/cats/cat.52.jpg
#   inflating: /content/Dataset/data_dogcat/train/cats/cat.53.jpg
#   inflating: /content/Dataset/data_dogcat/train/cats/cat.54.jpg
#   inflating: /content/Dataset/data_dogcat/train/cats/cat.55.jpg
#   inflating: /content/Dataset/data_dogcat/train/cats/cat.56.jpg
#   inflating: /content/Dataset/data_dogcat/train/cats/cat.57.jpg
#   inflating: /content/Dataset/data_dogcat/train/cats/cat.58.jpg
#   inflating: /content/Dataset/data_dogcat/train/cats/cat.59.jpg
#   inflating: /content/Dataset/data_dogcat/train/cats/cat.6.jpg
#   inflating: /content/Dataset/data_dogcat/train/cats/cat.7.jpg
#   inflating: /content/Dataset/data_dogcat/train/cats/cat.8.jpg
#   inflating: /content/Dataset/data_dogcat/train/cats/cat.9.jpg
#    creating: /content/Dataset/data_dogcat/train/dogs/
#   inflating: /content/Dataset/data_dogcat/train/dogs/dog.0.jpg
#   inflating: /content/Dataset/data_dogcat/train/dogs/dog.1.jpg
#   inflating: /content/Dataset/data_dogcat/train/dogs/dog.10.jpg
#   inflating: /content/Dataset/data_dogcat/train/dogs/dog.11.jpg
#   inflating: /content/Dataset/data_dogcat/train/dogs/dog.12.jpg
#   inflating: /content/Dataset/data_dogcat/train/dogs/dog.13.jpg
#   inflating: /content/Dataset/data_dogcat/train/dogs/dog.14.jpg
#   inflating: /content/Dataset/data_dogcat/train/dogs/dog.15.jpg
#   inflating: /content/Dataset/data_dogcat/train/dogs/dog.16.jpg
#   inflating: /content/Dataset/data_dogcat/train/dogs/dog.17.jpg
#   inflating: /content/Dataset/data_dogcat/train/dogs/dog.18.jpg
#   inflating: /content/Dataset/data_dogcat/train/dogs/dog.19.jpg
#   inflating: /content/Dataset/data_dogcat/train/dogs/dog.2.jpg
#   inflating: /content/Dataset/data_dogcat/train/dogs/dog.20.jpg
#   inflating: /content/Dataset/data_dogcat/train/dogs/dog.21.jpg
#   inflating: /content/Dataset/data_dogcat/train/dogs/dog.22.jpg
#   inflating: /content/Dataset/data_dogcat/train/dogs/dog.23.jpg
#   inflating: /content/Dataset/data_dogcat/train/dogs/dog.24.jpg
#   inflating: /content/Dataset/data_dogcat/train/dogs/dog.25.jpg
#   inflating: /content/Dataset/data_dogcat/train/dogs/dog.26.jpg
#   inflating: /content/Dataset/data_dogcat/train/dogs/dog.27.jpg
#   inflating: /content/Dataset/data_dogcat/train/dogs/dog.28.jpg
#   inflating: /content/Dataset/data_dogcat/train/dogs/dog.29.jpg
#   inflating: /content/Dataset/data_dogcat/train/dogs/dog.3.jpg
#   inflating: /content/Dataset/data_dogcat/train/dogs/dog.30.jpg
#   inflating: /content/Dataset/data_dogcat/train/dogs/dog.31.jpg
#   inflating: /content/Dataset/data_dogcat/train/dogs/dog.32.jpg
#   inflating: /content/Dataset/data_dogcat/train/dogs/dog.33.jpg
#   inflating: /content/Dataset/data_dogcat/train/dogs/dog.34.jpg
#   inflating: /content/Dataset/data_dogcat/train/dogs/dog.35.jpg
#   inflating: /content/Dataset/data_dogcat/train/dogs/dog.36.jpg
#   inflating: /content/Dataset/data_dogcat/train/dogs/dog.37.jpg
#   inflating: /content/Dataset/data_dogcat/train/dogs/dog.38.jpg
#   inflating: /content/Dataset/data_dogcat/train/dogs/dog.39.jpg
#   inflating: /content/Dataset/data_dogcat/train/dogs/dog.4.jpg
#   inflating: /content/Dataset/data_dogcat/train/dogs/dog.40.jpg
#   inflating: /content/Dataset/data_dogcat/train/dogs/dog.41.jpg
#   inflating: /content/Dataset/data_dogcat/train/dogs/dog.42.jpg
#   inflating: /content/Dataset/data_dogcat/train/dogs/dog.43.jpg
#   inflating: /content/Dataset/data_dogcat/train/dogs/dog.44.jpg
#   inflating: /content/Dataset/data_dogcat/train/dogs/dog.45.jpg
#   inflating: /content/Dataset/data_dogcat/train/dogs/dog.46.jpg
#   inflating: /content/Dataset/data_dogcat/train/dogs/dog.47.jpg
#   inflating: /content/Dataset/data_dogcat/train/dogs/dog.48.jpg
#   inflating: /content/Dataset/data_dogcat/train/dogs/dog.49.jpg
#   inflating: /content/Dataset/data_dogcat/train/dogs/dog.5.jpg
#   inflating: /content/Dataset/data_dogcat/train/dogs/dog.50.jpg
#   inflating: /content/Dataset/data_dogcat/train/dogs/dog.51.jpg
#   inflating: /content/Dataset/data_dogcat/train/dogs/dog.52.jpg
#   inflating: /content/Dataset/data_dogcat/train/dogs/dog.53.jpg
#   inflating: /content/Dataset/data_dogcat/train/dogs/dog.54.jpg
#   inflating: /content/Dataset/data_dogcat/train/dogs/dog.55.jpg
#   inflating: /content/Dataset/data_dogcat/train/dogs/dog.56.jpg
#   inflating: /content/Dataset/data_dogcat/train/dogs/dog.57.jpg
#   inflating: /content/Dataset/data_dogcat/train/dogs/dog.58.jpg
#   inflating: /content/Dataset/data_dogcat/train/dogs/dog.59.jpg
#   inflating: /content/Dataset/data_dogcat/train/dogs/dog.6.jpg
#   inflating: /content/Dataset/data_dogcat/train/dogs/dog.7.jpg
#   inflating: /content/Dataset/data_dogcat/train/dogs/dog.8.jpg
#   inflating: /content/Dataset/data_dogcat/train/dogs/dog.9.jpg

# %%
import zipfile
import os

# Semak jika Dataset.zip wujud di Colab
if os.path.exists('/content/Dataset.zip'):
    with zipfile.ZipFile('/content/Dataset.zip', 'r') as zip_ref:
        zip_ref.extractall('/content/dataset')
    print("Dataset.zip berjaya diekstrak ke /content/dataset!")
else:
    print("Fail Dataset.zip TIADA! Sila upload fail Dataset.zip ke bar sisi (Folder 📁) dahulu.")
# Out:
# Dataset.zip berjaya diekstrak ke /content/dataset!

# %%
# ==============================================================================
# PENTAKSIRAN BERTERUSAN AMALI 1: KV-TRON CNN VISION TRAINING
# KURSUS: DKA3223 - ARTIFICIAL INTELLIGENCE FOR COMPUTER VISION
# ==============================================================================

# LANGKAH 1: Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')

# LANGKAH 2: Tetapkan Laluan Dataset (FIX ME 1)
import os

# [FIX ME 1]: Gantikan "FIX_ME" dengan laluan folder dataset sebenar dalam Drive anda
dataset_path = "/content/Dataset/data_dogcat"  # Contoh: "/content/drive/MyDrive/KVTRON_CNN_Dataset"

if dataset_path == "FIX_ME":
    print("[BELUM LENGKAP] Gantikan dataset_path dengan lokasi folder sebenar.")
else:
    train_dir = dataset_path + "/train"
    test_dir = dataset_path + "/test"
    print("Train folder exists:", os.path.exists(train_dir))
    print("Test folder exists :", os.path.exists(test_dir))
    if os.path.exists(train_dir): print("Train classes:", os.listdir(train_dir))
    if os.path.exists(test_dir): print("Test classes :", os.listdir(test_dir))

# Import Pustaka PyTorch
import torch
import torch.nn as nn
import torch.optim as optim
import matplotlib.pyplot as plt
from torch.utils.data import DataLoader
from torchvision import datasets, transforms

torch.manual_seed(42)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Peranti digunakan:", device)

# LANGKAH 3: Konfigurasi Transformasi Imej (Image Transforms)
train_transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor()
])

test_transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor()
])
print("[SEDIA] Image transforms telah ditetapkan.")

# LANGKAH 4: Memuatkan Dataset Menggunakan ImageFolder
if "train_dir" not in globals() or "test_dir" not in globals():
    print("[BELUM SEDIA] Lengkapkan dataset_path dahulu.")
    train_dataset = test_dataset = None
else:
    train_dataset = datasets.ImageFolder(root=train_dir, transform=train_transform)
    test_dataset = datasets.ImageFolder(root=test_dir, transform=test_transform)
    print("Class names     :", train_dataset.classes)
    print("Class mapping   :", train_dataset.class_to_idx)
    print("Training images :", len(train_dataset))
    print("Testing images  :", len(test_dataset))

# LANGKAH 5: Membina DataLoader & Visualisasi Sampel
if train_dataset is None or test_dataset is None:
    print("[BELUM SEDIA] Load dataset dahulu.")
    train_loader = test_loader = None
else:
    train_loader = DataLoader(train_dataset, batch_size=16, shuffle=True)
    test_loader = DataLoader(test_dataset, batch_size=16, shuffle=False)

    images, labels = next(iter(train_loader))
    print("Batch image shape:", images.shape)
    print("Batch label shape:", labels.shape)

    plt.figure(figsize=(10,4))
    for i in range(min(4, len(images))):
        image = images[i].permute(1,2,0)
        class_name = train_dataset.classes[labels[i].item()]
        plt.subplot(1,4,i+1)
        plt.imshow(image)
        plt.title(class_name)
        plt.axis("off")
    plt.show()

# LANGKAH 6: Pembinaan Model CNN (FIX ME 2)
# [FIX ME 2]: Nyatakan bilangan saluran masukan (RGB) dan bilangan kelas output
INPUT_CHANNELS = 3  # Nyatakan integer yang betul
OUTPUT_CLASSES = 2  # Nyatakan integer yang betul

class CatDogCNN(nn.Module):
    def __init__(self):
        super().__init__()
        if INPUT_CHANNELS is None or OUTPUT_CLASSES is None:
            raise ValueError("Lengkapkan INPUT_CHANNELS dan OUTPUT_CLASSES dahulu.")

        self.features = nn.Sequential(
            nn.Conv2d(INPUT_CHANNELS, 16, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(2),
            nn.Conv2d(16, 32, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(2),
            nn.Conv2d(32, 64, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(2)
        )
        self.classifier = nn.Sequential(
            nn.Flatten(),
            nn.Linear(50176, 128),
            nn.ReLU(),
            nn.Linear(128, OUTPUT_CLASSES)
        )

    def forward(self, x):
        return self.classifier(self.features(x))

try:
    model = CatDogCNN().to(device)
    print(model)
except Exception as e:
    model = None
    print("[BELUM LENGKAP]", e)

# LANGKAH 7: Tetapan Latihan Model / Hyperparameters (FIX ME 3)
if model is None:
    print("[BELUM SEDIA] Lengkapkan model dahulu.")
    criterion = optimizer = epochs = None
else:
    # [FIX ME 3]: Definisi fungsi kerugian, pengoptimum Adam (lr=0.001), dan epoch=3
    criterion = nn.CrossEntropyLoss()  # Tetapkan fungsi CrossEntropyLoss
    optimizer = optim.Adam(model.parameters(), lr=0.001)  # Tetapkan pengoptimum Adam untuk model.parameters()
    epochs = 3     # Tetapkan integer epoch (contoh: 3)

    if criterion is None or optimizer is None or epochs is None:
        print("[BELUM LENGKAP] Lengkapkan criterion, optimizer dan epochs.")

# LANGKAH 8: Gelung Latihan (Training Loop)
if model is None or train_loader is None or criterion is None or optimizer is None or epochs is None:
    print("[BELUM SEDIA] Lengkapkan dataset, model dan training setup dahulu.")
    training_complete = False
else:
    for epoch in range(epochs):
        model.train()
        running_loss = 0.0
        correct = 0
        total = 0

        for images, labels in train_loader:
            images, labels = images.to(device), labels.to(device)
            optimizer.zero_grad()
            outputs = model(images)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            running_loss += loss.item()
            predicted = torch.argmax(outputs, dim=1)
            correct += (predicted == labels).sum().item()
            total += labels.size(0)

        accuracy = correct / total if total else 0
        print(f"Epoch {epoch+1}/{epochs}: Loss={running_loss:.4f}, Accuracy={accuracy:.4f}")

    training_complete = True

# LANGKAH 9: Penilaian Model dan Infrans Imej Tunggal
if not globals().get("training_complete", False):
    print("[BELUM SEDIA] Train model dahulu.")
else:
    model.eval()
    correct = 0
    total = 0
    with torch.no_grad():
        for images, labels in test_loader:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            predicted = torch.argmax(outputs, dim=1)
            correct += (predicted == labels).sum().item()
            total += labels.size(0)

    test_accuracy = correct / total if total else 0
    print("Test Accuracy:", f"{test_accuracy:.4f}")

    # Ujian Infrans Imej Pertama
    image, actual_label = test_dataset[0]
    with torch.no_grad():
        output = model(image.unsqueeze(0).to(device))
        predicted_label = torch.argmax(output, dim=1).item()

    predicted_class = test_dataset.classes[predicted_label]
    actual_class = test_dataset.classes[actual_label]

    plt.figure(figsize=(4,4))
    plt.imshow(image.permute(1,2,0))
    plt.title(f"Predicted: {predicted_class} | Actual: {actual_class}")
    plt.axis("off")
    plt.show()

# LANGKAH 10: Menyimpan Model (.pth) ke Google Drive
save_dir = "/content/drive/MyDrive/Colab Notebooks"
save_path = os.path.join(save_dir, "kvtron_catdog_cnn_model.pth")

if globals().get("training_complete", False):
    os.makedirs(save_dir, exist_ok=True)
    torch.save(model.state_dict(), save_path)
    print("Model disimpan sebagai:", save_path)
else:
    print("Model belum disimpan kerana training_complete masih False.")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Train folder exists: True
# Test folder exists : True
# Train classes: ['dogs', 'cats']
# Test classes : ['dogs', 'cats']
# Peranti digunakan: cpu
# [SEDIA] Image transforms telah ditetapkan.
# Class names     : ['cats', 'dogs']
# Class mapping   : {'cats': 0, 'dogs': 1}
# Training images : 120
# Testing images  : 99
# Batch image shape: torch.Size([16, 3, 224, 224])
# Batch label shape: torch.Size([16])
# CatDogCNN(
#   (features): Sequential(
#     (0): Conv2d(3, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): Conv2d(16, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): ReLU()
#     (5): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (6): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (7): ReLU()
#     (8): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (0): Flatten(start_dim=1, end_dim=-1)
#     (1): Linear(in_features=50176, out_features=128, bias=True)
#     (2): ReLU()
#     (3): Linear(in_features=128, out_features=2, bias=True)
#   )
# )
# Epoch 1/3: Loss=5.6617, Accuracy=0.4750
# Epoch 2/3: Loss=5.5836, Accuracy=0.5000
# Epoch 3/3: Loss=5.5602, Accuracy=0.5000
# Test Accuracy: 0.4848
# Model disimpan sebagai: /content/drive/MyDrive/Colab Notebooks/kvtron_catdog_cnn_model.pth

# %% [markdown]
# # PENTAKSIRAN BERTERUSAN AMALI 1: KV-TRON CNN VISION TRAINING
# ### KURSUS: DKA3223 - ARTIFICIAL INTELLIGENCE FOR COMPUTER VISION
#
# **Maklumat Calon:**
# * **Nama Calon: MARHANA HUMAIRA A'AQILA BINTI MOHD EFFENZY**
# * **Angka Giliran: PKV0125KA002**
#
# **Pernyataan Etika & Privasi:**
# * **Hak Cipta Dataset:** Dataset ini digunakan semata-mata bagi tujuan amali DKA3223 di Kolej Vokasional Balik Pulau. Hak cipta milik pemilik asal.
# * **Etika AI:** Model ini dibangunkan dengan mematuhi standard kebolehulangan (reproducibility) serta pengurusan kod dan data visual yang selamat.
